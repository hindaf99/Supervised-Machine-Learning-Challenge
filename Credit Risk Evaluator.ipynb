# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))

train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
# ...

# %%
X_train_df = train_df.drop(['loan_status'], axis= 1)
X_train = pd.get_dummies(X_train_df)
        
y_train_df = train_df['loan_status']


y_train_ = pd.get_dummies(y_train_df)

y_train= y_train_['high_risk'].rename({'high_risk': 'loan_status'})

#X_train= X_train.drop(['debt_settlement_flag_Y'], axis = 1)
y_train.shape
# Out:
# (12180,)

# %%
#X_train = X_train_dum.drop(['debt_settlement_flag_Y'], axis= 1)
#X_train

# %%
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))
test_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107      13375    0.1797       483.34       MORTGAGE
# 1      141451  141451      21000    0.1308       478.68       MORTGAGE
# 2      321143  321143      20000    0.1240       448.95       MORTGAGE
# 3       11778   11778       3000    0.1240       100.22           RENT
# 4      169382  169382      30000    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
# ...

# %%
X_test_df = test_df.drop(['loan_status'], axis= 1)
                
X_test = pd.get_dummies(X_test_df)

y_test_df= test_df['loan_status']

y_test_ = pd.get_dummies(y_test_df)

y_test= y_train_['high_risk'].rename({'high_risk': 'loan_status'})

X_test
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  \
# 0           57107   57107      13375    0.1797       483.34    223000.0
# 1          141451  141451      21000    0.1308       478.68    123000.0
# 2          321143  321143      20000    0.1240       448.95    197000.0
# 3           11778   11778       3000    0.1240       100.22     45000.0
# 4          169382  169382      30000    0.1612      1056.49    133000.0
# ...           ...     ...        ...       ...          ...         ...
# 12175      354912  354912      19975    0.2565       801.09     28000.0
# 12176      354944  354944      15000    0.1774       540.34     50000.0
# 12177      354973  354973       3600    0.1862       131.28     60000.0
# 12178      355002  355002      15000    0.0881       475.68     62000.0
# 12179      355307  355307      15000    0.1774       540.34     54080.0
#
#          dti  delinq_2yrs  inq_last_6mths  open_acc  ...  \
# ...

# %%
# add missing dummy variables to testing set

missing_cols = set( X_train.columns ) - set( X_test.columns )
for c in missing_cols:
    X_test[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
X_test = X_test[X_train.columns]
X_test
# Out:
#        Unnamed: 0   index  loan_amnt  int_rate  installment  annual_inc  \
# 0           57107   57107      13375    0.1797       483.34    223000.0
# 1          141451  141451      21000    0.1308       478.68    123000.0
# 2          321143  321143      20000    0.1240       448.95    197000.0
# 3           11778   11778       3000    0.1240       100.22     45000.0
# 4          169382  169382      30000    0.1612      1056.49    133000.0
# ...           ...     ...        ...       ...          ...         ...
# 12175      354912  354912      19975    0.2565       801.09     28000.0
# 12176      354944  354944      15000    0.1774       540.34     50000.0
# 12177      354973  354973       3600    0.1862       131.28     60000.0
# 12178      355002  355002      15000    0.0881       475.68     62000.0
# 12179      355307  355307      15000    0.1774       540.34     54080.0
#
#          dti  delinq_2yrs  inq_last_6mths  open_acc  ...  \
# ...

# %%
train_list= list(X_train.columns)
test_list= list(X_test.columns)

for col in train_list:
    if col not in test_list:
         print(col)

# %% [markdown]
# I predict that randome forest classification model will perform better.

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.6485221674876848

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier( n_estimators=200).fit(X_train, y_train)
print(f'Model Score: {clf.score(X_test, y_test)}')
print(f'Model Score: {clf.score(X_train, y_train)}')
# Out:
# Model Score: 1.0
# Model Score: 1.0

# %% [markdown]
# My prediction is correct because LR doesn’t handle large number of categorical features/variables well

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# I predict that randome forest classification model will always be the better ont since the score is 100% before and after scaling

# %%
# Train the Logistic Regression model on the scaled data and print the model score
model.fit(X_train_scaled, y_train)

model.score(X_test_scaled, y_test)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.713136288998358

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clf.fit(X_train_scaled, y_train)
print(f'Model Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Model Score: 1.0

# %%
clf.predict(X_test_scaled)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=uint8)

# %% [markdown]
# LR is always lower than RFC even after scaling
